# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as pt
import seaborn as sns

# %%
df = pd.read_csv(
    '/Users/sanskargupta/Downloads/Rishab_Mishra_Python_Projects/Python_Diwali_Sales_Analysis-main/Diwali Sales Data.csv',
    encoding='ISO-8859-1'
)

# %%
df.shape
# Out:
# (11251, 15)

# %%
df.head(10)
# Out:
#    User_ID  Cust_name Product_ID Gender Age Group  Age  Marital_Status  \
# 0  1002903  Sanskriti  P00125942      F     26-35   28               0
# 1  1000732     Kartik  P00110942      F     26-35   35               1
# 2  1001990      Bindu  P00118542      F     26-35   35               1
# 3  1001425     Sudevi  P00237842      M      0-17   16               0
# 4  1000588       Joni  P00057942      M     26-35   28               1
# 5  1000588       Joni  P00057942      M     26-35   28               1
# 6  1001132       Balk  P00018042      F     18-25   25               1
# 7  1002092   Shivangi  P00273442      F       55+   61               0
# 8  1003224     Kushal  P00205642      M     26-35   35               0
# 9  1003650      Ginny  P00031142      F     26-35   26               1
#
#               State      Zone       Occupation Product_Category  Orders  \
# 0       Maharashtra   Western       Healthcare             Auto       1
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 11251 entries, 0 to 11250
# Data columns (total 15 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   User_ID           11251 non-null  int64
#  1   Cust_name         11251 non-null  object
#  2   Product_ID        11251 non-null  object
#  3   Gender            11251 non-null  object
#  4   Age Group         11251 non-null  object
#  5   Age               11251 non-null  int64
#  6   Marital_Status    11251 non-null  int64
#  7   State             11251 non-null  object
#  8   Zone              11251 non-null  object
#  9   Occupation        11251 non-null  object
#  10  Product_Category  11251 non-null  object
#  11  Orders            11251 non-null  int64
#  12  Amount            11239 non-null  float64
#  13  Status            0 non-null      float64
#  14  unnamed1          0 non-null      float64
# dtypes: float64(3), int64(4), object(8)
# memory usage: 1.3+ MB

# %%
df.drop(['Status','unnamed1'], axis=1, inplace=True)

# %%
pd.isnull(df).sum()
# Out:
# User_ID              0
# Cust_name            0
# Product_ID           0
# Gender               0
# Age Group            0
# Age                  0
# Marital_Status       0
# State                0
# Zone                 0
# Occupation           0
# Product_Category     0
# Orders               0
# Amount              12
# dtype: int64

# %%
df.dropna(inplace=True)

# %%
df['Amount']=df['Amount'].astype('int')

# %%
df.columns
# Out:
# Index(['User_ID', 'Cust_name', 'Product_ID', 'Gender', 'Age Group', 'Age',
#        'Marital_Status', 'State', 'Zone', 'Occupation', 'Product_Category',
#        'Orders', 'Amount'],
#       dtype='object')

# %%
df.rename(columns={'Marital_Status': 'Shaadi'})
# Out:
#        User_ID    Cust_name Product_ID Gender Age Group  Age  Shaadi  \
# 0      1002903    Sanskriti  P00125942      F     26-35   28       0
# 1      1000732       Kartik  P00110942      F     26-35   35       1
# 2      1001990        Bindu  P00118542      F     26-35   35       1
# 3      1001425       Sudevi  P00237842      M      0-17   16       0
# 4      1000588         Joni  P00057942      M     26-35   28       1
# ...        ...          ...        ...    ...       ...  ...     ...
# 11246  1000695      Manning  P00296942      M     18-25   19       1
# 11247  1004089  Reichenbach  P00171342      M     26-35   33       0
# 11248  1001209        Oshin  P00201342      F     36-45   40       0
# 11249  1004023       Noonan  P00059442      M     36-45   37       0
# 11250  1002744      Brumley  P00281742      F     18-25   19       0
#
#                 State      Zone       Occupation Product_Category  Orders  \
# ...

# %%
df.describe()
# Out:
#             User_ID           Age  Marital_Status        Orders        Amount
# count  1.123900e+04  11239.000000    11239.000000  11239.000000  11239.000000
# mean   1.003004e+06     35.410357        0.420055      2.489634   9453.610553
# std    1.716039e+03     12.753866        0.493589      1.114967   5222.355168
# min    1.000001e+06     12.000000        0.000000      1.000000    188.000000
# 25%    1.001492e+06     27.000000        0.000000      2.000000   5443.000000
# 50%    1.003064e+06     33.000000        0.000000      2.000000   8109.000000
# 75%    1.004426e+06     43.000000        1.000000      3.000000  12675.000000
# max    1.006040e+06     92.000000        1.000000      4.000000  23952.000000

# %%
df[['Age','Orders','Amount']].describe()
# Out:
#                 Age        Orders        Amount
# count  11239.000000  11239.000000  11239.000000
# mean      35.410357      2.489634   9453.610553
# std       12.753866      1.114967   5222.355168
# min       12.000000      1.000000    188.000000
# 25%       27.000000      2.000000   5443.000000
# 50%       33.000000      2.000000   8109.000000
# 75%       43.000000      3.000000  12675.000000
# max       92.000000      4.000000  23952.000000

# %%
#Exploratory Data Analysis

# %%
#Gender

# %%
df.columns
# Out:
# Index(['User_ID', 'Cust_name', 'Product_ID', 'Gender', 'Age Group', 'Age',
#        'Marital_Status', 'State', 'Zone', 'Occupation', 'Product_Category',
#        'Orders', 'Amount'],
#       dtype='object')

# %%
ax = sns.countplot(x='Gender',data=df)

for bars in ax.containers:
    ax.bar_label(bars)

# %%
sales_gen= df.groupby(['Gender'],as_index=False)['Amount'].sum().sort_values(by='Amount',ascending=False)
sns.barplot(x='Gender',y='Amount',data=sales_gen)
# Out:
# <Axes: xlabel='Gender', ylabel='Amount'>

# %% [raw]
# from above graphs we can say that most buyers are women and even the purchasing power of females are greater than men

# %% [markdown]
# Age

# %%
ax = sns.countplot(x='Age Group',data=df,hue= 'Gender')

for bars in ax.containers:
    ax.bar_label(bars)

# %%
sales_gen= df.groupby(['Age Group'],as_index=False)['Amount'].sum().sort_values(by='Amount',ascending=False)
sns.barplot(x='Age Group',y='Amount',data=sales_gen)
# Out:
# <Axes: xlabel='Age Group', ylabel='Amount'>

# %% [raw]
# From Above graphs we can say that most buyers are bewteen the age of 26 to 35 years female

# %%
#State

# %%
#Total number of orders from top 10 states
sales_state= df.groupby(['State'],as_index=False)['Orders'].sum().sort_values(by='Orders',ascending=False).head(10)
sns.barplot(x='State',y='Orders',data=sales_state)

sns.set(rc={'figure.figsize':(20,5)})

# %%
#Total Amount/Sales from top 10 states
sales_state= df.groupby(['State'],as_index=False)['Amount'].sum().sort_values(by='Amount',ascending=False).head(10)
sns.barplot(x='State',y='Amount',data=sales_state)

sns.set(rc={'figure.figsize':(20,5)})

# %% [raw]
# #From above graph we can see that the state with most orders is Uttar Pradesh, followed by Maharshtra, Karnataka and Delhi.

# %%
#Martial Status

# %%
ax = sns.countplot(x='Marital_Status',data=df)

for bars in ax.containers:
    ax.bar_label(bars)
    sns.set(rc={'figure.figsize':(2,5)})

# %%
sales_state= df.groupby(['Marital_Status','Gender'],as_index=False)['Amount'].sum().sort_values(by='Amount',ascending=False)
sns.barplot(x='Marital_Status',y='Amount',data=sales_state, hue='Gender')

sns.set(rc={'figure.figsize':(6,5)})

# %% [raw]
# From above graph we can say that most number of buyers are married females, and they also have higher purchasing power

# %%
#Occupation

# %%
ax = sns.countplot(x='Occupation',data=df)

for bars in ax.containers:
    ax.bar_label(bars)
    sns.set(rc={'figure.figsize':(30,5)})

# %%
sales_state= df.groupby(['Occupation'],as_index=False)['Amount'].sum().sort_values(by='Amount',ascending=False)
sns.barplot(x='Occupation',y='Amount',data=sales_state)

sns.set(rc={'figure.figsize':(30,5)})

# %% [raw]
# From above graphs we can see that most number of buyers are from health care center,
# but the purchasing power of IT sector is higher as compared to HealthCare sector

# %%
#Product Category

# %%
ax = sns.countplot(x='Product_Category',data=df)

for bars in ax.containers:
    ax.bar_label(bars)
    sns.set(rc={'figure.figsize':(25,5)})

# %%
sales_state= df.groupby(['Product_Category'],as_index=False)['Amount'].sum().sort_values(by='Amount',ascending=False).head(10)
sns.barplot(x='Product_Category',y='Amount',data=sales_state)

sns.set(rc={'figure.figsize':(30,5)})

# %% [raw]
# From above graphs we can see that highest orders are from clothing and apparel category
# But category food on the other hand has the highest purchase power

# %% [raw]
# Conclusion
# Based on the exploratory data analysis of the Diwali Sales dataset, the following key business insights were identified:
#
# Women are the primary customers, contributing a significantly higher number of purchases as well as greater overall spending compared to men.
# The 26–35 years age group, particularly female customers, represents the most valuable customer segment, making them an ideal target audience for marketing campaigns.
# Uttar Pradesh generates the highest number of orders, followed by Maharashtra, Karnataka, and Delhi, indicating that these states are the strongest markets for sales and customer acquisition.
# Married women account for the largest share of buyers and exhibit the highest purchasing power, suggesting that promotional campaigns and festive offers should primarily focus on this demographic.
# While the Healthcare sector has the highest number of customers, customers from the IT sector spend more on average, making them a high-value customer segment for premium products and personalized marketing.
# Clothing & Apparel is the most popular product category in terms of order volume, whereas the Food category generates the highest total revenue, indicating stronger customer spending in that category.
#
# Overall, the analysis suggests that the company's most profitable customer profile consists of married women aged 26–35 years from Uttar Pradesh, Maharashtra, Karnataka, and Delhi, particularly those working in the IT and Healthcare sectors. Focusing marketing efforts, personalized promotions, and inventory planning around these customer segments and high-performing product categories can help improve sales, customer engagement, and overall business profitability.
